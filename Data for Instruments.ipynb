# %%
import audio_processing as ap
import audio_utils as au
import math
import numpy.fft as fft
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Guitar

# %%
f_g = au.read_wav_mono('audio_files/guitar/guitar_A4_very-long_forte_normal.wav')
au.graph_signal(f_g)
print(ap.fundamental(f_g))
# Out:
# 441.908890626

# %%
step= int(44100 / 4)
start = 11025
chunk_g = f_g[start:start+step]
s_g = fft.rfft(chunk_g)
au.graph_fft(s_g, 6000)

# %%
w_g = ap.hann_window(chunk_g)
s_g = fft.rfft(w_g)
au.graph_fft(s_g, 10000)
print(ap.spectral_centroid(s_g))
# Out:
# 1270.00868967

# %%
s_g = ap.spectral_flux(f_g)
au.graph_signal(s_g, 16)

# %% [markdown]
# ## Saxophone

# %%
# f_s = au.read_wav_mono('audio_files/saxophone/saxophone_A4_15_forte_normal.wav')
f_s = au.read_wav_mono('audio_files/saxophone/saxophone_A5_15_fortissimo_normal.wav')
au.graph_signal(f_s)
print(ap.fundamental(f_s[:44100]))
# Out:
# 858.961044851

# %%
step= int(44100 / 4)
start = 11025
chunk_s = f_s[start:start+step]
s_s = fft.rfft(ap.hann_window(f_s[:44100]))
au.graph_fft(s_s, 6000)

# %%
w_s = ap.hann_window(chunk_s)
s_s = fft.rfft(w_s)
au.graph_fft(s_s, 6000)

# %%
s_s = ap.spectral_flux(f_s)
au.graph_signal(s_s)

# %% [markdown]
# ## Violin

# %%
f_v = au.read_wav_mono('audio_files/violin/violin_A3_025_pianissimo_arco-normal.wav')
print(len(f_v))
au.graph_signal(f_v)
print(ap.fundamental(f_v))
# Out:
# 48384
# 440.216178233

# %%
step= int(44100 / 4)
start = 11025
chunk_v = f_v[start:start+step]
s_v = fft.rfft(chunk_v)
au.graph_fft(s_v, 6000)

# %%
w_v = ap.hann_window(chunk_v)
s_v = fft.rfft(w_v)
print(ap.spectral_centroid(s_v))
au.graph_fft(s_v, 6000)
# Out:
# 1769.43566207

# %%
s_v = ap.spectral_flux(f_v)
au.graph_signal(s_v, 16)

# %% [markdown]
# ## Testing some new functions

# %%
w = au.read_wav_mono('audio_files/saxophone/saxophone_B4_025_pianissimo_normal.wav')
au.graph_signal(w)

# %%
s = fft.rfft(w)
au.graph_fft(s, 6000)

# %%
(start, end) = au.get_good_chunk(s)

ch_s = fft.rfft( ap.hann_window(clarinet) )
au.graph_fft(ch_s, 6000)
